# %%
#installer
# BW:
# top seller actual
# 1000 reviews 333 je category

# %%
#import libaries
import pandas as pd
import steamreviews
import json
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# # DEV

# %% [markdown]
# ## Update steamdata.py

# %% [markdown]
# ## preprocessing.py

# %%
#!pip install pyspellchecker
#!pip install emoji
import re
import emoji
from spellchecker import SpellChecker
# Out:
# ...
# WARNING: You are using pip version 20.2.3; however, version 23.2.1 is available.
# You should consider upgrading via the 'c:\users\bernhard\appdata\local\programs\python\python38\python.exe -m pip install --upgrade pip' command.

# %%
# final dataset
df['review_preprocessed'] = df['review'] # copy column

# spellchecker - takes a very long time
spell = SpellChecker()
df["review_preprocessed"] = [' '.join([spell.correction(i) for i in x.split()]) for x in df['review_preprocessed']]

df['review_preprocessed'] = df['review_preprocessed'].str.replace(r'\d+','') # remove numbers
df['review_preprocessed'] = df['review_preprocessed'].str.replace(r'\n',' ') # remove line breaks
df['review_preprocessed'] = df['review_preprocessed'].str.replace(r'\t',' ') # remove tabs
df['review_preprocessed'] = df['review_preprocessed'].str.replace('[^\w\s]','') #remove punctuation

df['review_preprocessed'] = emoji.demojize(df['review_preprocessed']) # translate emojis

df['review_preprocessed'] = df['review'].str.lower() # lowercase

# %%
df
# Out:
# 0       my friend who i play cs:go with said if i post...
# 1       i really loved playing through the prologue! p...
# 2       soul's spectrum: awakening is a game that real...
# 3       the traps and puzzles in the game are so varie...
# 4       soul's spectrum: awakening is a free prequel t...
#                               ...
# 2239                               no gay sex, zero stars
# 2240                             super fun but gacha bad.
# 2241                   add nude patch and i will play it.
# 2242    ok game, fun for a bit but then just kinda sta...
# 2243    cash grab low effort game. it's bascially an a...
# Name: review_preprocessed, Length: 2244, dtype: object

# %%
# tokenization

# %%
# remove stopwords

# %%
spell = SpellChecker()
df["spell_check"] = [' '.join([spell.correction(i) for i in x.split()]) for x in df['review_preprocessed']]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\Bernhard\OneDrive - FH Technikum Wien\MDS_3_WS2023\NLP\Project\MDS-3-SPZ-NLP\dev\dev_bw.ipynb Zelle 10 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/Bernhard/OneDrive%20-%20FH%20Technikum%20Wien/MDS_3_WS2023/NLP/Project/MDS-3-SPZ-NLP/dev/dev_bw.ipynb#X34sZmlsZQ%3D%3D?line=0'>1</a> spell = SpellChecker()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Bernhard/OneDrive%20-%20FH%20Technikum%20Wien/MDS_3_WS2023/NLP/Project/MDS-3-SPZ-NLP/dev/dev_bw.ipynb#X34sZmlsZQ%3D%3D?line=1'>2</a> df["spell_check"] = [' '.join([spell.correction(i) for i in x.split()]) for x in df['review_preprocessed']]
#
# c:\Users\Bernhard\OneDrive - FH Technikum Wien\MDS_3_WS2023\NLP\Project\MDS-3-SPZ-NLP\dev\dev_bw.ipynb Zelle 10 line 2
# ...

# %%
#convert emoji to text

emoji.demojize(df['emoticons'])

def find_emojis(text):
    return emoji.demojize(text)

df['emoticons'] = df['review_preprocessed'].apply(find_emojis)
for emoticons in df['emoticons']:
    print(emoticons)
# Out:
# my friend who i play cs:go with said if i post a review on soul's spectrum: awakening and it gets 75 likes and 30 awards that he will buy me a rtx 3060 and 1 kilo of lemon . so im just gonna leave this here. help a brotha
# i really loved playing through the prologue! puzzles are good for starting to learn how the game works, but still really fun and challenging!
# graphics are really polished and pleasant to watch, and the adaptive soundtrack is really nice!
# being the prologue the story doesn't start yet, but the dialogues gave me a sense of mistery, and now i'm really looking forward to play the complete game! :d
# soul's spectrum: awakening is a game that really captures from the first minutes and does not let go until the very end. as a fan of fantasy and role-playing games, i was pleasantly surprised by the depth and interest that this game offered me.
#
# ...

# %%
# preprocessing of the data
app_ids = [2586870, 1497440, 1036240, 1902690, 1607250]
data_list = get_data(app_ids)
df = pd.DataFrame(data_list)
# Out:
# Loading idprocessed_on_20231001.txt
# Creating idprocessed_on_20231001.txt
# ...
# [appID = 2586870] expected #reviews = 52
# [appID = 2586870] num_reviews = 52 (expected: 52)
# ...
# [appID = 1497440] expected #reviews = 109
# [appID = 1497440] num_reviews = 109 (expected: 109)
# ...
# [appID = 1036240] expected #reviews = 554
# [appID = 1036240] num_reviews = 554 (expected: 554)
# ...
# [appID = 1902690] expected #reviews = 239
# [appID = 1902690] num_reviews = 244 (expected: 239)
# ...
# [appID = 1607250] expected #reviews = 1278
# [appID = 1607250] num_reviews = 1285 (expected: 1278)
# Game records written: 5

# %%
# review data in lowercase
df['review_preprocessed'] = df['review'] # copy column
df['review_preprocessed'] = df['review'].str.lower() # lowercase
df['review_preprocessed'] = df['review_preprocessed'].str.replace(r'\d+','') # remove numbers
df['review_preprocessed'] = df['review_preprocessed'].str.replace(r'\n',' ') # remove line breaks

# Regulärer Ausdruck, um Emoticons zu extrahieren (Dieser Ausdruck erfasst Emoticons, die aus einem oder mehreren Buchstaben bestehen)
regex_pattern = r'[^\w\s]'

# Emoticons in der 'reviews'-Spalte finden und in eine neue Spalte 'emoticons' schreiben
df['emoticons'] = df['review'].str.findall(regex_pattern)

# Ergebnis anzeigen
df
# Out:
#        app_id recommendationid  \
# 0     2586870        147379813
# 1     2586870        147376402
# 2     2586870        147372568
# 3     2586870        147369693
# 4     2586870        147364446
# ...       ...              ...
# 2239  1607250        147386006
# 2240  1607250        147385883
# 2241  1607250        147385803
# 2242  1607250        147385492
# 2243  1607250        147385182
#
#                                                  review  voted_up  votes_up  \
# 0     My friend who I play CS:GO with said if I post...      True         4
# 1     I really loved playing through the prologue! P...      True         1
# 2     Soul's Spectrum: Awakening is a game that real...      True         0
# 3     The traps and puzzles in the game are so varie...      True         0
# 4     Soul's Spectrum: Awakening is a free prequel t...      True         0
# ...                                                 ...       ...       ...
# ...

# %% [markdown]
# # HELP

# %% [markdown]
# ## get ids from best of 2022

# %%
# gamelist
from bs4 import BeautifulSoup

# HTML-Code from table (copy from website)
html = '''
<table class="weeklytopsellers_ChartTable_3arZn"><thead class="weeklytopsellers_ColumnHeaders_3eKiI"><tr><th class="weeklytopsellers_HoverCell_3Jiuz"></th><th class="weeklytopsellers_Rank_2BuNW" colspan="2"><span>Platz</span></th><th class="weeklytopsellers_RightCell__iRXB weeklytopsellers_Price_amGaR"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">Preis <svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 100 100" x="0px" y="0px"><path d="M50,7A43,43,0,1,1,7,50,43,43,0,0,1,50,7m0-7a50,50,0,1,0,50,50A50,50,0,0,0,50,0h0Z" fill="currentColor"></path><path d="M50.79,25a45.51,45.51,0,0,1,5.29.87c5.33,1.51,8.5,5.77,8.9,11.43a10.4,10.4,0,0,1-4.21,9.5c-1.42,1.1-2.91,2.1-4.34,3.18a7.06,7.06,0,0,0-3.18,6.3,4,4,0,0,1-2.88,4,4.42,4.42,0,0,1-5.18-1.55,4.19,4.19,0,0,1-.59-2.07A13.89,13.89,0,0,1,50.3,45,41.55,41.55,0,0,0,54.83,41,5,5,0,0,0,56,38.19c0.23-2.83-1.59-4.65-4.52-4.84-3.54-.23-6.52.69-8.6,3.82a4.19,4.19,0,0,1-4.35,2c-3-.5-4.29-2.94-3.06-5.75a12.84,12.84,0,0,1,6.25-6.2A21.71,21.71,0,0,1,50.79,25Z" fill="currentColor"></path><path d="M53.78,69.88C53.8,73.09,52,75,48.85,75s-5.25-1.84-5.26-4.53c0-3.73,1.67-5.59,5-5.69C51.3,64.7,54.12,66.36,53.78,69.88Z" fill="currentColor"></path></svg></div></th><th class="weeklytopsellers_Change_150QP" align="right"><div class="weeklytopsellers_Tooltip_2OA1J Focusable"><span>Änderung</span> <svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 100 100" x="0px" y="0px"><path d="M50,7A43,43,0,1,1,7,50,43,43,0,0,1,50,7m0-7a50,50,0,1,0,50,50A50,50,0,0,0,50,0h0Z" fill="currentColor"></path><path d="M50.79,25a45.51,45.51,0,0,1,5.29.87c5.33,1.51,8.5,5.77,8.9,11.43a10.4,10.4,0,0,1-4.21,9.5c-1.42,1.1-2.91,2.1-4.34,3.18a7.06,7.06,0,0,0-3.18,6.3,4,4,0,0,1-2.88,4,4.42,4.42,0,0,1-5.18-1.55,4.19,4.19,0,0,1-.59-2.07A13.89,13.89,0,0,1,50.3,45,41.55,41.55,0,0,0,54.83,41,5,5,0,0,0,56,38.19c0.23-2.83-1.59-4.65-4.52-4.84-3.54-.23-6.52.69-8.6,3.82a4.19,4.19,0,0,1-4.35,2c-3-.5-4.29-2.94-3.06-5.75a12.84,12.84,0,0,1,6.25-6.2A21.71,21.71,0,0,1,50.79,25Z" fill="currentColor"></path><path d="M53.78,69.88C53.8,73.09,52,75,48.85,75s-5.25-1.84-5.26-4.53c0-3.73,1.67-5.59,5-5.69C51.3,64.7,54.12,66.36,53.78,69.88Z" fill="currentColor"></path></svg></div></th><th class="weeklytopsellers_Weeks_1ODme" align="right"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">Wochen <svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 100 100" x="0px" y="0px"><path d="M50,7A43,43,0,1,1,7,50,43,43,0,0,1,50,7m0-7a50,50,0,1,0,50,50A50,50,0,0,0,50,0h0Z" fill="currentColor"></path><path d="M50.79,25a45.51,45.51,0,0,1,5.29.87c5.33,1.51,8.5,5.77,8.9,11.43a10.4,10.4,0,0,1-4.21,9.5c-1.42,1.1-2.91,2.1-4.34,3.18a7.06,7.06,0,0,0-3.18,6.3,4,4,0,0,1-2.88,4,4.42,4.42,0,0,1-5.18-1.55,4.19,4.19,0,0,1-.59-2.07A13.89,13.89,0,0,1,50.3,45,41.55,41.55,0,0,0,54.83,41,5,5,0,0,0,56,38.19c0.23-2.83-1.59-4.65-4.52-4.84-3.54-.23-6.52.69-8.6,3.82a4.19,4.19,0,0,1-4.35,2c-3-.5-4.29-2.94-3.06-5.75a12.84,12.84,0,0,1,6.25-6.2A21.71,21.71,0,0,1,50.79,25Z" fill="currentColor"></path><path d="M53.78,69.88C53.8,73.09,52,75,48.85,75s-5.25-1.84-5.26-4.53c0-3.73,1.67-5.59,5-5.69C51.3,64.7,54.12,66.36,53.78,69.88Z" fill="currentColor"></path></svg></div></th></tr></thead><tbody><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">1</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/730/CounterStrike_2?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/730/capsule_231x87.jpg?t=1696011820"><div class="weeklytopsellers_GameName_1n_4-">Counter-Strike 2</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer"><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">Kostenlos spielbar</div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh Up"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">▲ 1</div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">581</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">2</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/2195250/EA_SPORTS_FC_24?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/2195250/capsule_231x87.jpg?t=1696034116"><div class="weeklytopsellers_GameName_1n_4-">EA SPORTS FC™ 24</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer"><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">69,99€</div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh Up"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">▲ 10</div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">11</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">3</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/1091500/Cyberpunk_2077?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/1091500/capsule_231x87.jpg?t=1695308476"><div class="weeklytopsellers_GameName_1n_4-">Cyberpunk 2077</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer salepreviewwidgets_Discounted_35-Ub Discounted"><div class="salepreviewwidgets_StoreSaleDiscountBox_2fpFv">-40%</div><div class="salepreviewwidgets_StoreSaleDiscountedPriceCtn_3GLeQ"><div class="salepreviewwidgets_StoreOriginalPrice_1EKGZ">59,99€</div><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">35,99€</div></div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh Up"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">▲ 5</div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">16</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">4</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/2138330/Cyberpunk_2077_Phantom_Liberty?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/2138330/capsule_231x87.jpg?t=1695740414"><div class="weeklytopsellers_GameName_1n_4-">Cyberpunk 2077: Phantom Liberty</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer"><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">29,99€</div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh Up"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">▲ 7</div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">7</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">5</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/bundle/32470/?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/bundles/32470/5htp7gjbzhjufq5c/capsule_231x87.jpg?t=1686506470"><div class="weeklytopsellers_GameName_1n_4-">Bundle: Cyberpunk 2077 &amp; Phantom Liberty </div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer salepreviewwidgets_Discounted_35-Ub Discounted"><span class="salepreviewwidgets_BaseDiscount_Kxr-3">-8%</span><div class="salepreviewwidgets_StoreSaleDiscountBox_2fpFv">-33%</div><div class="salepreviewwidgets_StoreSaleDiscountedPriceCtn_3GLeQ"><div class="salepreviewwidgets_StoreOriginalPrice_1EKGZ">89,98€</div><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">60,70€</div></div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh"><div class="weeklytopsellers_Tooltip_2OA1J Focusable"><span class="weeklytopsellers_ListWeeksDebut_3VOg1">Neu</span></div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">1</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">6</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/1086940/Baldurs_Gate_3?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/1086940/capsule_231x87.jpg?t=1695393586"><div class="weeklytopsellers_GameName_1n_4-">Baldur's Gate 3</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer"><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">59,99€</div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh Down"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">▼ 3</div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">16</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">7</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/1938090/Call_of_Duty?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/1938090/capsule_231x87.jpg?t=1695840716"><div class="weeklytopsellers_GameName_1n_4-">Call of Duty®</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh Up"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">▲ 2</div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">59</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">8</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/1627720/Lies_of_P?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/1627720/capsule_231x87.jpg?t=1695272170"><div class="weeklytopsellers_GameName_1n_4-">Lies of P</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer"><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">59,99€</div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh Down"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">▼ 1</div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">2</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">9</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/1716740/Starfield?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/1716740/capsule_231x87.jpg?t=1694716152"><div class="weeklytopsellers_GameName_1n_4-">Starfield</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer"><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">69,99€</div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh Down"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">▼ 5</div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">16</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">10</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/1599340/Lost_Ark?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/1599340/capsule_231x87.jpg?t=1695752294"><div class="weeklytopsellers_GameName_1n_4-">Lost Ark</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer"><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">Kostenlos spielbar</div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh Down"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">▼ 4</div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">91</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">11</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/1260320/Party_Animals?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/1260320/capsule_231x87.jpg?t=1695243290"><div class="weeklytopsellers_GameName_1n_4-">Party Animals</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer"><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">17,99€</div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh Up"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">▲ 83</div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">2</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">12</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/1172620/Sea_of_Thieves_2023_Edition?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/1172620/capsule_231x87.jpg?t=1689874808"><div class="weeklytopsellers_GameName_1n_4-">Sea of Thieves 2023 Edition</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer salepreviewwidgets_Discounted_35-Ub Discounted"><div class="salepreviewwidgets_StoreSaleDiscountBox_2fpFv">-50%</div><div class="salepreviewwidgets_StoreSaleDiscountedPriceCtn_3GLeQ"><div class="salepreviewwidgets_StoreOriginalPrice_1EKGZ">39,99€</div><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">19,99€</div></div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh Up"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">▲ 75</div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">13</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">13</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/306130/The_Elder_Scrolls_Online?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/306130/capsule_231x87_alt_assets_12.jpg?t=1696006182"><div class="weeklytopsellers_GameName_1n_4-">The Elder Scrolls® Online</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer salepreviewwidgets_Discounted_35-Ub Discounted"><div class="salepreviewwidgets_StoreSaleDiscountBox_2fpFv">-70%</div><div class="salepreviewwidgets_StoreSaleDiscountedPriceCtn_3GLeQ"><div class="salepreviewwidgets_StoreOriginalPrice_1EKGZ">19,99€</div><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">5,99€</div></div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh Up"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">▲ 35</div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">448</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">14</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/949230/Cities_Skylines_II?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/949230/capsule_231x87.jpg?t=1695903055"><div class="weeklytopsellers_GameName_1n_4-">Cities: Skylines II</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer"><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8 salepreviewwidgets_StoreSalePrepurchaseLabel_Wxeyn">Vorbestellen</div><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">49,99€</div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh Up"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">▲ 1</div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">16</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">15</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/236390/War_Thunder?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/236390/capsule_231x87.jpg?t=1695124816"><div class="weeklytopsellers_GameName_1n_4-">War Thunder</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer"><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">Kostenlos spielbar</div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh Down"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">▼ 1</div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">252</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">16</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/1272080/PAYDAY_3?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/1272080/capsule_231x87.jpg?t=1695809097"><div class="weeklytopsellers_GameName_1n_4-">PAYDAY 3</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer"><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">39,99€</div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh Down"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">▼ 11</div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">8</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">17</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/899770/Last_Epoch?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/899770/capsule_231x87.jpg?t=1694102346"><div class="weeklytopsellers_GameName_1n_4-">Last Epoch</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer"><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">33,99€</div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh Up"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">▲ 72</div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">3</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">18</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/359550/Tom_Clancys_Rainbow_Six_Siege?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/359550/capsule_231x87.jpg?t=1694635629"><div class="weeklytopsellers_GameName_1n_4-">Tom Clancy's Rainbow Six® Siege</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer"><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">19,99€</div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh"><div class="weeklytopsellers_Tooltip_2OA1J Focusable"> 0</div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">412</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">19</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/1675200/Steam_Deck?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/1675200/capsule_231x87.jpg?t=1691453048"><div class="weeklytopsellers_GameName_1n_4-">Steam Deck</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer"><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">419,00€</div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh Down"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">▼ 18</div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">83</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">20</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/570/Dota_2?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/570/capsule_231x87.jpg?t=1682639497"><div class="weeklytopsellers_GameName_1n_4-">Dota 2</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer"><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">Kostenlos spielbar</div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh Up"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">▲ 21</div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">7</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">21</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/1172470/Apex_Legends?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/1172470/capsule_231x87.jpg?t=1695930392"><div class="weeklytopsellers_GameName_1n_4-">Apex Legends™</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer"><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">Kostenlos spielbar</div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh Down"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">▼ 8</div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">151</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">22</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/2362300/Train_Sim_World_4?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/2362300/capsule_231x87.jpg?t=1695824748"><div class="weeklytopsellers_GameName_1n_4-">Train Sim World® 4</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer salepreviewwidgets_Discounted_35-Ub Discounted"><div class="salepreviewwidgets_StoreSaleDiscountBox_2fpFv">-35%</div><div class="salepreviewwidgets_StoreSaleDiscountedPriceCtn_3GLeQ"><div class="salepreviewwidgets_StoreOriginalPrice_1EKGZ">55,98€</div><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">36,39€</div></div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh"><div class="weeklytopsellers_Tooltip_2OA1J Focusable"><span class="weeklytopsellers_ListWeeksDebut_3VOg1">Neu</span></div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">1</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">23</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/2080690/Sunkenland?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/2080690/capsule_231x87.jpg?t=1695842283"><div class="weeklytopsellers_GameName_1n_4-">Sunkenland</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer"><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">19,50€</div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh Down"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">▼ 3</div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">5</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">24</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/2531820/Call_of_Duty_Modern_Warfare_II__BlackCell_Saison_6?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/2531820/capsule_231x87.jpg?t=1695830405"><div class="weeklytopsellers_GameName_1n_4-">Call of Duty®: Modern Warfare® II - BlackCell (Saison 6)</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer"><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">29,99€</div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh"><div class="weeklytopsellers_Tooltip_2OA1J Focusable"><span class="weeklytopsellers_ListWeeksDebut_3VOg1">Neu</span></div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">1</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">25</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/1084160/Jagged_Alliance_3?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/1084160/capsule_231x87.jpg?t=1695815841"><div class="weeklytopsellers_GameName_1n_4-">Jagged Alliance 3</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer salepreviewwidgets_Discounted_35-Ub Discounted"><div class="salepreviewwidgets_StoreSaleDiscountBox_2fpFv">-34%</div><div class="salepreviewwidgets_StoreSaleDiscountedPriceCtn_3GLeQ"><div class="salepreviewwidgets_StoreOriginalPrice_1EKGZ">44,99€</div><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">29,69€</div></div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh"><div class="weeklytopsellers_Tooltip_2OA1J Focusable"><span class="weeklytopsellers_ListWeeksDebut_3VOg1">Neu</span></div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">1</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">26</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/381210/Dead_by_Daylight?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/381210/capsule_231x87.jpg?t=1694008105"><div class="weeklytopsellers_GameName_1n_4-">Dead by Daylight</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer"><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">19,99€</div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh Up"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">▲ 3</div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">335</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">27</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/230410/Warframe?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/230410/capsule_231x87.jpg?t=1693084453"><div class="weeklytopsellers_GameName_1n_4-">Warframe</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer"><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">Kostenlos spielbar</div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh Up"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">▲ 30</div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">43</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">28</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/1937780/Total_War_PHARAOH?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/1937780/capsule_231x87_alt_assets_0.jpg?t=1695825020"><div class="weeklytopsellers_GameName_1n_4-">Total War: PHARAOH</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer"><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8 salepreviewwidgets_StoreSalePrepurchaseLabel_Wxeyn">Vorbestellen</div><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">59,99€</div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh"><div class="weeklytopsellers_Tooltip_2OA1J Focusable"><span class="weeklytopsellers_ListWeeksDebut_3VOg1">Neu</span></div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">1</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">29</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/271590/Grand_Theft_Auto_V?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/271590/capsule_231x87.jpg?t=1695060909"><div class="weeklytopsellers_GameName_1n_4-">Grand Theft Auto V</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer salepreviewwidgets_Discounted_35-Ub Discounted"><div class="salepreviewwidgets_StoreSaleDiscountBox_2fpFv">-25%</div><div class="salepreviewwidgets_StoreSaleDiscountedPriceCtn_3GLeQ"><div class="salepreviewwidgets_StoreOriginalPrice_1EKGZ">39,98€</div><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">29,98€</div></div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh Up"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">▲ 6</div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">454</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">30</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/1971870/Mortal_Kombat_1?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/1971870/capsule_231x87.jpg?t=1695922812"><div class="weeklytopsellers_GameName_1n_4-">Mortal Kombat 1</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer"><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">69,99€</div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh Down"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">▼ 20</div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">3</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">31</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/1551360/Forza_Horizon_5?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/1551360/capsule_231x87.jpg?t=1694801571"><div class="weeklytopsellers_GameName_1n_4-">Forza Horizon 5</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer"><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">59,99€</div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh Up"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">▲ 19</div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">109</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">32</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/1248130/Farming_Simulator_22?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/1248130/capsule_231x87.jpg?t=1680158089"><div class="weeklytopsellers_GameName_1n_4-">Farming Simulator 22</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer"><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">29,99€</div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh Up"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">▲ 2</div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">118</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">33</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/1282100/Remnant_II?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/1282100/capsule_231x87.jpg?t=1691690139"><div class="weeklytopsellers_GameName_1n_4-">Remnant II</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer"><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">49,99€</div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh"><div class="weeklytopsellers_Tooltip_2OA1J Focusable"><span class="weeklytopsellers_ListWeeksDebut_3VOg1">Neu</span></div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">1</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">34</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/1244460/Jurassic_World_Evolution_2?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/1244460/capsule_231x87.jpg?t=1691666733"><div class="weeklytopsellers_GameName_1n_4-">Jurassic World Evolution 2</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer salepreviewwidgets_Discounted_35-Ub Discounted"><div class="salepreviewwidgets_StoreSaleDiscountBox_2fpFv">-70%</div><div class="salepreviewwidgets_StoreSaleDiscountedPriceCtn_3GLeQ"><div class="salepreviewwidgets_StoreOriginalPrice_1EKGZ">59,99€</div><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">17,99€</div></div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh"><div class="weeklytopsellers_Tooltip_2OA1J Focusable"><span class="weeklytopsellers_ListWeeksDebut_3VOg1">Neu</span></div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">1</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">35</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/594650/Hunt_Showdown?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/594650/capsule_231x87.jpg?t=1688573408"><div class="weeklytopsellers_GameName_1n_4-">Hunt: Showdown</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer salepreviewwidgets_Discounted_35-Ub Discounted"><div class="salepreviewwidgets_StoreSaleDiscountBox_2fpFv">-60%</div><div class="salepreviewwidgets_StoreSaleDiscountedPriceCtn_3GLeQ"><div class="salepreviewwidgets_StoreOriginalPrice_1EKGZ">39,99€</div><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">15,99€</div></div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh Up"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">▲ 33</div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">2</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">36</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/2440510/Forza_Motorsport?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/2440510/capsule_231x87.jpg?t=1696010427"><div class="weeklytopsellers_GameName_1n_4-">Forza Motorsport</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer"><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8 salepreviewwidgets_StoreSalePrepurchaseLabel_Wxeyn">Vorbestellen</div><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">69,99€</div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh Up"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">▲ 42</div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">2</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">37</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/39210/FINAL_FANTASY_XIV_Online?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/39210/capsule_231x87.jpg?t=1693964220"><div class="weeklytopsellers_GameName_1n_4-">FINAL FANTASY XIV Online</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer"><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">9,99€</div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh Up"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">▲ 6</div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">43</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">38</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/1326470/Sons_Of_The_Forest?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/1326470/capsule_231x87.jpg?t=1679677298"><div class="weeklytopsellers_GameName_1n_4-">Sons Of The Forest</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer"><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">28,99€</div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh Up"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">▲ 15</div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">31</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">39</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/1158310/Crusader_Kings_III?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/1158310/capsule_231x87.jpg?t=1692714098"><div class="weeklytopsellers_GameName_1n_4-">Crusader Kings III</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer"><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">49,99€</div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh Up"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">▲ 53</div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">2</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">40</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/394360/Hearts_of_Iron_IV?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/394360/capsule_231x87.jpg?t=1695630955"><div class="weeklytopsellers_GameName_1n_4-">Hearts of Iron IV</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer"><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">39,99€</div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh Up"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">▲ 33</div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">17</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">41</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/582660/Black_Desert?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/582660/capsule_231x87.jpg?t=1695920923"><div class="weeklytopsellers_GameName_1n_4-">Black Desert</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer"><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">9,99€</div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh Down"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">▼ 13</div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">135</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">42</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/2290180/Riders_Republic?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/2290180/capsule_231x87.jpg?t=1694711764"><div class="weeklytopsellers_GameName_1n_4-">Riders Republic</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer salepreviewwidgets_Discounted_35-Ub Discounted"><div class="salepreviewwidgets_StoreSaleDiscountBox_2fpFv">-75%</div><div class="salepreviewwidgets_StoreSaleDiscountedPriceCtn_3GLeQ"><div class="salepreviewwidgets_StoreOriginalPrice_1EKGZ">39,99€</div><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">9,99€</div></div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh"><div class="weeklytopsellers_Tooltip_2OA1J Focusable"><span class="weeklytopsellers_ListWeeksDebut_3VOg1">Neu</span></div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">1</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">43</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/1902690/FateSamurai_Remnant?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/1902690/capsule_231x87.jpg?t=1695962179"><div class="weeklytopsellers_GameName_1n_4-">Fate/Samurai Remnant</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer"><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">69,99€</div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh"><div class="weeklytopsellers_Tooltip_2OA1J Focusable"><span class="weeklytopsellers_ListWeeksDebut_3VOg1">Neu</span></div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">1</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">44</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/bundle/33909/?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/bundles/33909/8tzap2ibscfszgi1/capsule_231x87.jpg?t=1695747704"><div class="weeklytopsellers_GameName_1n_4-">Train Sim World® 4: Austrian Regional Edition</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer salepreviewwidgets_Discounted_35-Ub Discounted"><div class="salepreviewwidgets_StoreSaleDiscountBox_2fpFv">-35%</div><div class="salepreviewwidgets_StoreSaleDiscountedPriceCtn_3GLeQ"><div class="salepreviewwidgets_StoreOriginalPrice_1EKGZ">55,98€</div><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">36,39€</div></div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh"><div class="weeklytopsellers_Tooltip_2OA1J Focusable"><span class="weeklytopsellers_ListWeeksDebut_3VOg1">Neu</span></div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">1</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">45</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/1151340/Fallout_76?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/1151340/capsule_231x87.jpg?t=1693430341"><div class="weeklytopsellers_GameName_1n_4-">Fallout 76</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer"><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">39,99€</div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh Up"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">▲ 55</div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">2</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">46</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/1085660/Destiny_2?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/1085660/capsule_231x87_german.jpg?t=1694626285"><div class="weeklytopsellers_GameName_1n_4-">Destiny 2</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer"><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">Kostenlos spielbar</div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh Down"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">▼ 24</div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">219</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">47</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/1449850/YuGiOh_Master_Duel?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/1449850/capsule_231x87.jpg?t=1692175666"><div class="weeklytopsellers_GameName_1n_4-">Yu-Gi-Oh! Master Duel</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer"><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">Kostenlos spielbar</div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh Up"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">▲ 24</div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">11</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">48</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/703080/Planet_Zoo?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/703080/capsule_231x87_alt_assets_1_german.jpg?t=1695117862"><div class="weeklytopsellers_GameName_1n_4-">Planet Zoo</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer"><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">44,99€</div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh"><div class="weeklytopsellers_Tooltip_2OA1J Focusable"><span class="weeklytopsellers_ListWeeksDebut_3VOg1">Neu</span></div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">1</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">49</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/252490/Rust?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/252490/capsule_231x87.jpg?t=1693652810"><div class="weeklytopsellers_GameName_1n_4-">Rust</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer"><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">39,99€</div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh Down"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">▼ 24</div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">262</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">50</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/bundle/27500/?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/bundles/27500/wodoifjnkc8eldpj/capsule_231x87.jpg?t=1691686282"><div class="weeklytopsellers_GameName_1n_4-">Quake-Collection-Paket</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer salepreviewwidgets_Discounted_35-Ub Discounted"><div class="salepreviewwidgets_StoreSaleDiscountBox_2fpFv">-25%</div><div class="salepreviewwidgets_StoreSaleDiscountedPriceCtn_3GLeQ"><div class="salepreviewwidgets_StoreOriginalPrice_1EKGZ">59,95€</div><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">44,96€</div></div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh"><div class="weeklytopsellers_Tooltip_2OA1J Focusable"><span class="weeklytopsellers_ListWeeksDebut_3VOg1">Neu</span></div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">1</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">51</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/1501750/Lords_of_the_Fallen?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/1501750/capsule_231x87.jpg?t=1695195898"><div class="weeklytopsellers_GameName_1n_4-">Lords of the Fallen</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer"><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8 salepreviewwidgets_StoreSalePrepurchaseLabel_Wxeyn">Vorbestellen</div><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">59,99€</div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh"><div class="weeklytopsellers_Tooltip_2OA1J Focusable"><span class="weeklytopsellers_ListWeeksDebut_3VOg1">Neu</span></div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">1</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">52</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/1059530/Valve_Index_VRHeadset?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/1059530/capsule_231x87.jpg?t=1645043152"><div class="weeklytopsellers_GameName_1n_4-">Valve Index VR-Headset</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer"><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">539,00€</div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh Down"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">▼ 22</div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">2</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">53</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/916440/Anno_1800?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/916440/capsule_231x87.jpg?t=1692033053"><div class="weeklytopsellers_GameName_1n_4-">Anno 1800</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer"><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">59,99€</div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh"><div class="weeklytopsellers_Tooltip_2OA1J Focusable"><span class="weeklytopsellers_ListWeeksDebut_3VOg1">Neu</span></div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">1</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">54</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/sub/124923/?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/subs/124923/capsule_231x87.jpg?t=1671055800"><div class="weeklytopsellers_GameName_1n_4-">The Witcher 3: Wild Hunt - Complete Edition</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer salepreviewwidgets_Discounted_35-Ub Discounted"><div class="salepreviewwidgets_StoreSaleDiscountBox_2fpFv">-70%</div><div class="salepreviewwidgets_StoreSaleDiscountedPriceCtn_3GLeQ"><div class="salepreviewwidgets_StoreOriginalPrice_1EKGZ">49,99€</div><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">14,99€</div></div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh"><div class="weeklytopsellers_Tooltip_2OA1J Focusable"><span class="weeklytopsellers_ListWeeksDebut_3VOg1">Neu</span></div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">1</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">55</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/578080/PUBG_BATTLEGROUNDS?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/578080/capsule_231x87.jpg?t=1694608943"><div class="weeklytopsellers_GameName_1n_4-">PUBG: BATTLEGROUNDS</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer"><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">Kostenlos spielbar</div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh Down"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">▼ 28</div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">28</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">56</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/292030/The_Witcher_3_Wild_Hunt?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/292030/capsule_231x87.jpg?t=1693590732"><div class="weeklytopsellers_GameName_1n_4-">The Witcher® 3: Wild Hunt</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer salepreviewwidgets_Discounted_35-Ub Discounted"><div class="salepreviewwidgets_StoreSaleDiscountBox_2fpFv">-70%</div><div class="salepreviewwidgets_StoreSaleDiscountedPriceCtn_3GLeQ"><div class="salepreviewwidgets_StoreOriginalPrice_1EKGZ">29,99€</div><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">8,99€</div></div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh"><div class="weeklytopsellers_Tooltip_2OA1J Focusable"><span class="weeklytopsellers_ListWeeksDebut_3VOg1">Neu</span></div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">1</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">57</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/255710/Cities_Skylines?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/255710/capsule_231x87.jpg?t=1692879552"><div class="weeklytopsellers_GameName_1n_4-">Cities: Skylines</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer"><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">27,99€</div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh Down"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">▼ 21</div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">47</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">58</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/bundle/5699/?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/bundles/5699/qipqf90z2z7h4x3i/capsule_231x87.jpg?t=1678931390"><div class="weeklytopsellers_GameName_1n_4-">Grand Theft Auto V: Premium Edition</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer salepreviewwidgets_Discounted_35-Ub Discounted"><div class="salepreviewwidgets_StoreSaleDiscountBox_2fpFv">-25%</div><div class="salepreviewwidgets_StoreSaleDiscountedPriceCtn_3GLeQ"><div class="salepreviewwidgets_StoreOriginalPrice_1EKGZ">39,98€</div><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">29,98€</div></div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh"><div class="weeklytopsellers_Tooltip_2OA1J Focusable"><span class="weeklytopsellers_ListWeeksDebut_3VOg1">Neu</span></div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">1</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">59</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/518790/theHunter_Call_of_the_Wild?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/518790/capsule_231x87.jpg?t=1692616457"><div class="weeklytopsellers_GameName_1n_4-">theHunter: Call of the Wild™</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer"><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">19,99€</div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh Up"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">▲ 21</div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">2</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">60</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/2108330/F1_23?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/2108330/capsule_231x87.jpg?t=1688987889"><div class="weeklytopsellers_GameName_1n_4-">F1® 23</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer"><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">69,99€</div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh Down"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">▼ 21</div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">21</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">61</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/294100/RimWorld?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/294100/capsule_231x87.jpg?t=1676391313"><div class="weeklytopsellers_GameName_1n_4-">RimWorld</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer salepreviewwidgets_Discounted_35-Ub Discounted"><div class="salepreviewwidgets_StoreSaleDiscountBox_2fpFv">-20%</div><div class="salepreviewwidgets_StoreSaleDiscountedPriceCtn_3GLeQ"><div class="salepreviewwidgets_StoreOriginalPrice_1EKGZ">31,99€</div><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">25,59€</div></div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh"><div class="weeklytopsellers_Tooltip_2OA1J Focusable"><span class="weeklytopsellers_ListWeeksDebut_3VOg1">Neu</span></div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">1</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">62</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/bundle/10422/?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/bundles/10422/kv1ko4pqyfj4brgr/capsule_231x87.jpg?t=1589988696"><div class="weeklytopsellers_GameName_1n_4-">Portal Knights -  Legendary Edition</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer salepreviewwidgets_Discounted_35-Ub Discounted"><div class="salepreviewwidgets_StoreSaleDiscountBox_2fpFv">-52%</div><div class="salepreviewwidgets_StoreSaleDiscountedPriceCtn_3GLeQ"><div class="salepreviewwidgets_StoreOriginalPrice_1EKGZ">61,90€</div><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">29,71€</div></div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh"><div class="weeklytopsellers_Tooltip_2OA1J Focusable"><span class="weeklytopsellers_ListWeeksDebut_3VOg1">Neu</span></div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">1</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">63</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/1222670/The_Sims_4?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/1222670/capsule_231x87_alt_assets_4.jpg?t=1695920644"><div class="weeklytopsellers_GameName_1n_4-">The Sims™ 4</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer"><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">Kostenlos spielbar</div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh Down"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">▼ 32</div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">171</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">64</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/1702010/Sengoku_Dynasty?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/1702010/capsule_231x87_alt_assets_1.jpg?t=1695305560"><div class="weeklytopsellers_GameName_1n_4-">Sengoku Dynasty</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer salepreviewwidgets_Discounted_35-Ub Discounted"><div class="salepreviewwidgets_StoreSaleDiscountBox_2fpFv">-15%</div><div class="salepreviewwidgets_StoreSaleDiscountedPriceCtn_3GLeQ"><div class="salepreviewwidgets_StoreOriginalPrice_1EKGZ">26,99€</div><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">22,94€</div></div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh"><div class="weeklytopsellers_Tooltip_2OA1J Focusable"><span class="weeklytopsellers_ListWeeksDebut_3VOg1">Neu</span></div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">1</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">65</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/1289670/EA_Play?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/1289670/capsule_231x87.jpg?t=1695670555"><div class="weeklytopsellers_GameName_1n_4-">EA Play</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer"><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">3,99€</div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh"><div class="weeklytopsellers_Tooltip_2OA1J Focusable"><span class="weeklytopsellers_ListWeeksDebut_3VOg1">Neu</span></div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">1</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">66</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/438040/Shakes_and_Fidget?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/438040/capsule_231x87_alt_assets_1.jpg?t=1695206097"><div class="weeklytopsellers_GameName_1n_4-">Shakes and Fidget</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer"><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">Kostenlos spielbar</div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh"><div class="weeklytopsellers_Tooltip_2OA1J Focusable"><span class="weeklytopsellers_ListWeeksDebut_3VOg1">Neu</span></div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">1</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">67</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/bundle/32454/?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/bundles/32454/7oywhb01knl8p4mk/capsule_231x87.jpg?t=1695050093"><div class="weeklytopsellers_GameName_1n_4-">Lies of P - Deluxe Edition</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer"><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">69,99€</div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh"><div class="weeklytopsellers_Tooltip_2OA1J Focusable"><span class="weeklytopsellers_ListWeeksDebut_3VOg1">Neu</span></div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">1</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">68</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/427520/Factorio?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/427520/capsule_231x87.jpg?t=1694021968"><div class="weeklytopsellers_GameName_1n_4-">Factorio</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer"><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">32,00€</div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh Down"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">▼ 3</div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">2</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">69</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/2248760/Car_For_Sale_Simulator_2023?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/2248760/capsule_231x87.jpg?t=1695066077"><div class="weeklytopsellers_GameName_1n_4-">Car For Sale Simulator 2023</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer"><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">17,49€</div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh"><div class="weeklytopsellers_Tooltip_2OA1J Focusable"><span class="weeklytopsellers_ListWeeksDebut_3VOg1">Neu</span></div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">1</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">70</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/1607250/MY_HERO_ULTRA_RUMBLE?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/1607250/capsule_231x87.jpg?t=1695940282"><div class="weeklytopsellers_GameName_1n_4-">MY HERO ULTRA RUMBLE</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer"><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">Kostenlos spielbar</div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh"><div class="weeklytopsellers_Tooltip_2OA1J Focusable"><span class="weeklytopsellers_ListWeeksDebut_3VOg1">Neu</span></div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">1</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">71</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/227300/Euro_Truck_Simulator_2?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/227300/capsule_231x87.jpg?t=1696087833"><div class="weeklytopsellers_GameName_1n_4-">Euro Truck Simulator 2</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer"><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">19,99€</div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh Down"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">▼ 55</div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">464</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">72</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/1250410/Microsoft_Flight_Simulator_40th_Anniversary_Edition?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/1250410/capsule_231x87.jpg?t=1689193265"><div class="weeklytopsellers_GameName_1n_4-">Microsoft Flight Simulator 40th Anniversary Edition</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer"><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">69,99€</div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh Down"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">▼ 53</div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">165</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">73</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/1286830/STAR_WARS_The_Old_Republic?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/1286830/capsule_231x87.jpg?t=1695312107"><div class="weeklytopsellers_GameName_1n_4-">STAR WARS™: The Old Republic™</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer"><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">Kostenlos spielbar</div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh"><div class="weeklytopsellers_Tooltip_2OA1J Focusable"><span class="weeklytopsellers_ListWeeksDebut_3VOg1">Neu</span></div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">1</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">74</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/440900/Conan_Exiles?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/440900/capsule_231x87_alt_assets_3_german.jpg?t=1695922148"><div class="weeklytopsellers_GameName_1n_4-">Conan Exiles</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer"><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">39,99€</div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh"><div class="weeklytopsellers_Tooltip_2OA1J Focusable"><span class="weeklytopsellers_ListWeeksDebut_3VOg1">Neu</span></div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">1</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">75</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/1096900/RPG_Maker_MZ?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/1096900/capsule_231x87.jpg?t=1695777190"><div class="weeklytopsellers_GameName_1n_4-">RPG Maker MZ</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer salepreviewwidgets_Discounted_35-Ub Discounted"><div class="salepreviewwidgets_StoreSaleDiscountBox_2fpFv">-50%</div><div class="salepreviewwidgets_StoreSaleDiscountedPriceCtn_3GLeQ"><div class="salepreviewwidgets_StoreOriginalPrice_1EKGZ">77,99€</div><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">38,99€</div></div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh"><div class="weeklytopsellers_Tooltip_2OA1J Focusable"><span class="weeklytopsellers_ListWeeksDebut_3VOg1">Neu</span></div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">1</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">76</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/bundle/5702/?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/bundles/5702/pply2cvg2eqlcmue/capsule_231x87.jpg?t=1670346494"><div class="weeklytopsellers_GameName_1n_4-">Grand Theft Auto V: Premium Edition &amp; Megalodon Shark Card Bundle</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer salepreviewwidgets_Discounted_35-Ub Discounted"><div class="salepreviewwidgets_StoreSaleDiscountBox_2fpFv">-36%</div><div class="salepreviewwidgets_StoreSaleDiscountedPriceCtn_3GLeQ"><div class="salepreviewwidgets_StoreOriginalPrice_1EKGZ">114,97€</div><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">73,58€</div></div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh"><div class="weeklytopsellers_Tooltip_2OA1J Focusable"><span class="weeklytopsellers_ListWeeksDebut_3VOg1">Neu</span></div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">1</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">77</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/2230110/Fae_Farm?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/2230110/capsule_231x87.jpg?t=1695392613"><div class="weeklytopsellers_GameName_1n_4-">Fae Farm</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer"><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">39,99€</div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh Down"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">▼ 37</div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">3</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">78</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/bundle/16852/?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/bundles/16852/vs00avpenw4wfhfp/capsule_231x87.jpg?t=1604588813"><div class="weeklytopsellers_GameName_1n_4-">Unity of Command II + DLC</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer salepreviewwidgets_Discounted_35-Ub Discounted"><div class="salepreviewwidgets_StoreSaleDiscountBox_2fpFv">-5%</div><div class="salepreviewwidgets_StoreSaleDiscountedPriceCtn_3GLeQ"><div class="salepreviewwidgets_StoreOriginalPrice_1EKGZ">92,68€</div><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">88,05€</div></div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh"><div class="weeklytopsellers_Tooltip_2OA1J Focusable"><span class="weeklytopsellers_ListWeeksDebut_3VOg1">Neu</span></div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">1</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">79</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/bundle/15456/?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/bundles/15456/sfnwy4y3z1krzw3d/capsule_231x87.jpg?t=1619785600"><div class="weeklytopsellers_GameName_1n_4-">Cities: Skylines - New Player Bundle</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer salepreviewwidgets_Discounted_35-Ub Discounted"><div class="salepreviewwidgets_StoreSaleDiscountBox_2fpFv">-10%</div><div class="salepreviewwidgets_StoreSaleDiscountedPriceCtn_3GLeQ"><div class="salepreviewwidgets_StoreOriginalPrice_1EKGZ">70,96€</div><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">63,86€</div></div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh"><div class="weeklytopsellers_Tooltip_2OA1J Focusable"><span class="weeklytopsellers_ListWeeksDebut_3VOg1">Neu</span></div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">1</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">80</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/2172860/The_Elder_Scrolls_Online_Necrom?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/2172860/capsule_231x87.jpg?t=1695920442"><div class="weeklytopsellers_GameName_1n_4-">The Elder Scrolls Online: Necrom</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer salepreviewwidgets_Discounted_35-Ub Discounted"><div class="salepreviewwidgets_StoreSaleDiscountBox_2fpFv">-50%</div><div class="salepreviewwidgets_StoreSaleDiscountedPriceCtn_3GLeQ"><div class="salepreviewwidgets_StoreOriginalPrice_1EKGZ">39,99€</div><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">19,99€</div></div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh"><div class="weeklytopsellers_Tooltip_2OA1J Focusable"><span class="weeklytopsellers_ListWeeksDebut_3VOg1">Neu</span></div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">1</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">81</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/1401590/Disney_Dreamlight_Valley?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/1401590/capsule_231x87.jpg?t=1689883856"><div class="weeklytopsellers_GameName_1n_4-">Disney Dreamlight Valley</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer"><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">29,99€</div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh Down"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">▼ 30</div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">2</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">82</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/bundle/12261/?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/bundles/12261/fooxyohgkvdhm2av/capsule_231x87.jpg?t=1652280228"><div class="weeklytopsellers_GameName_1n_4-">Frostpunk: Game of the Year Edition</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer salepreviewwidgets_Discounted_35-Ub Discounted"><div class="salepreviewwidgets_StoreSaleDiscountBox_2fpFv">-30%</div><div class="salepreviewwidgets_StoreSaleDiscountedPriceCtn_3GLeQ"><div class="salepreviewwidgets_StoreOriginalPrice_1EKGZ">64,96€</div><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">45,47€</div></div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh"><div class="weeklytopsellers_Tooltip_2OA1J Focusable"><span class="weeklytopsellers_ListWeeksDebut_3VOg1">Neu</span></div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">1</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">83</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/1063730/New_World?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/1063730/capsule_231x87.jpg?t=1695753023"><div class="weeklytopsellers_GameName_1n_4-">New World</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer"><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">39,99€</div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh Down"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">▼ 29</div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">13</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">84</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/1547000/Grand_Theft_Auto_San_Andreas__The_Definitive_Edition?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/1547000/capsule_231x87.jpg?t=1676922466"><div class="weeklytopsellers_GameName_1n_4-">Grand Theft Auto: San Andreas – The Definitive Edition</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer salepreviewwidgets_Discounted_35-Ub Discounted"><div class="salepreviewwidgets_StoreSaleDiscountBox_2fpFv">-50%</div><div class="salepreviewwidgets_StoreSaleDiscountedPriceCtn_3GLeQ"><div class="salepreviewwidgets_StoreOriginalPrice_1EKGZ">59,99€</div><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">29,99€</div></div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh"><div class="weeklytopsellers_Tooltip_2OA1J Focusable"><span class="weeklytopsellers_ListWeeksDebut_3VOg1">Neu</span></div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">1</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">85</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/1008080/SYNCED?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/1008080/capsule_231x87.jpg?t=1695308048"><div class="weeklytopsellers_GameName_1n_4-">SYNCED</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer"><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">Kostenlos spielbar</div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh Down"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">▼ 36</div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">3</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">86</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/284160/BeamNGdrive?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/284160/capsule_231x87.jpg?t=1695207686"><div class="weeklytopsellers_GameName_1n_4-">BeamNG.drive</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer"><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">20,99€</div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh"><div class="weeklytopsellers_Tooltip_2OA1J Focusable"><span class="weeklytopsellers_ListWeeksDebut_3VOg1">Neu</span></div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">1</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">87</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/962130/Grounded?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/962130/capsule_231x87.jpg?t=1684963474"><div class="weeklytopsellers_GameName_1n_4-">Grounded</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer salepreviewwidgets_Discounted_35-Ub Discounted"><div class="salepreviewwidgets_StoreSaleDiscountBox_2fpFv">-33%</div><div class="salepreviewwidgets_StoreSaleDiscountedPriceCtn_3GLeQ"><div class="salepreviewwidgets_StoreOriginalPrice_1EKGZ">39,99€</div><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">26,79€</div></div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh"><div class="weeklytopsellers_Tooltip_2OA1J Focusable"><span class="weeklytopsellers_ListWeeksDebut_3VOg1">Neu</span></div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">1</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">88</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/bundle/26372/?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/bundles/26372/vmkp3uvk3bji1fgy/capsule_231x87.jpg?t=1680695854"><div class="weeklytopsellers_GameName_1n_4-">Generation Zero ® - Base Warfare Starter Bundle</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer salepreviewwidgets_Discounted_35-Ub Discounted"><div class="salepreviewwidgets_StoreSaleDiscountBox_2fpFv">-14%</div><div class="salepreviewwidgets_StoreSaleDiscountedPriceCtn_3GLeQ"><div class="salepreviewwidgets_StoreOriginalPrice_1EKGZ">42,94€</div><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">36,93€</div></div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh"><div class="weeklytopsellers_Tooltip_2OA1J Focusable"><span class="weeklytopsellers_ListWeeksDebut_3VOg1">Neu</span></div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">1</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">89</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/266410/iRacing?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/266410/capsule_231x87.jpg?t=1685469538"><div class="weeklytopsellers_GameName_1n_4-">iRacing</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer"><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">10,99€</div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh"><div class="weeklytopsellers_Tooltip_2OA1J Focusable"><span class="weeklytopsellers_ListWeeksDebut_3VOg1">Neu</span></div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">1</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">90</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/2050650/Resident_Evil_4?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/2050650/capsule_231x87.jpg?t=1695311474"><div class="weeklytopsellers_GameName_1n_4-">Resident Evil 4</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer"><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">59,99€</div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh Down"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">▼ 64</div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">2</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">91</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/1985810/Call_of_Duty_Black_Ops_Cold_War?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/1985810/capsule_231x87.jpg?t=1686345977"><div class="weeklytopsellers_GameName_1n_4-">Call of Duty®: Black Ops Cold War</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer"><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">59,99€</div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh Down"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">▼ 44</div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">2</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">92</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/444200/World_of_Tanks_Blitz?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/444200/capsule_231x87.jpg?t=1695911636"><div class="weeklytopsellers_GameName_1n_4-">World of Tanks Blitz</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer"><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">Kostenlos spielbar</div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh"><div class="weeklytopsellers_Tooltip_2OA1J Focusable"><span class="weeklytopsellers_ListWeeksDebut_3VOg1">Neu</span></div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">1</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">93</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/289070/Sid_Meiers_Civilization_VI?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/289070/capsule_231x87.jpg?t=1680898825"><div class="weeklytopsellers_GameName_1n_4-">Sid Meier’s Civilization® VI</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer salepreviewwidgets_Discounted_35-Ub Discounted"><div class="salepreviewwidgets_StoreSaleDiscountBox_2fpFv">-91%</div><div class="salepreviewwidgets_StoreSaleDiscountedPriceCtn_3GLeQ"><div class="salepreviewwidgets_StoreOriginalPrice_1EKGZ">167,91€</div><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">14,77€</div></div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh"><div class="weeklytopsellers_Tooltip_2OA1J Focusable"><span class="weeklytopsellers_ListWeeksDebut_3VOg1">Neu</span></div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">1</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">94</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/bundle/25716/?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/bundles/25716/pyfrnwts751r8p0d/capsule_231x87_german.jpg?t=1680818519"><div class="weeklytopsellers_GameName_1n_4-">Disney Dreamlight Valley - Ultimative Edition</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer salepreviewwidgets_Discounted_35-Ub Discounted"><div class="salepreviewwidgets_StoreSaleDiscountBox_2fpFv">-30%</div><div class="salepreviewwidgets_StoreSaleDiscountedPriceCtn_3GLeQ"><div class="salepreviewwidgets_StoreOriginalPrice_1EKGZ">99,98€</div><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">69,99€</div></div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh"><div class="weeklytopsellers_Tooltip_2OA1J Focusable"><span class="weeklytopsellers_ListWeeksDebut_3VOg1">Neu</span></div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">1</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">95</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/1677740/Stumble_Guys?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/1677740/capsule_231x87.jpg?t=1695750859"><div class="weeklytopsellers_GameName_1n_4-">Stumble Guys</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer"><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">Kostenlos spielbar</div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh"><div class="weeklytopsellers_Tooltip_2OA1J Focusable"><span class="weeklytopsellers_ListWeeksDebut_3VOg1">Neu</span></div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">1</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">96</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/1599330/Wildmender?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/1599330/capsule_231x87.jpg?t=1695979030"><div class="weeklytopsellers_GameName_1n_4-">Wildmender</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer salepreviewwidgets_Discounted_35-Ub Discounted"><div class="salepreviewwidgets_StoreSaleDiscountBox_2fpFv">-10%</div><div class="salepreviewwidgets_StoreSaleDiscountedPriceCtn_3GLeQ"><div class="salepreviewwidgets_StoreOriginalPrice_1EKGZ">24,99€</div><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">22,49€</div></div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh"><div class="weeklytopsellers_Tooltip_2OA1J Focusable"><span class="weeklytopsellers_ListWeeksDebut_3VOg1">Neu</span></div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">1</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">97</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/990080/Hogwarts_Legacy?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/990080/capsule_231x87.jpg?t=1694060626"><div class="weeklytopsellers_GameName_1n_4-">Hogwarts Legacy</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer"><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">59,99€</div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh"><div class="weeklytopsellers_Tooltip_2OA1J Focusable"><span class="weeklytopsellers_ListWeeksDebut_3VOg1">Neu</span></div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">1</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">98</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/1142710/Total_War_WARHAMMER_III?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/1142710/capsule_231x87.jpg?t=1691504594"><div class="weeklytopsellers_GameName_1n_4-">Total War: WARHAMMER III</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer"><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">59,99€</div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh Down"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">▼ 65</div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">7</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">99</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/app/1273400/BauSimulator?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/apps/1273400/capsule_231x87_german.jpg?t=1694708196"><div class="weeklytopsellers_GameName_1n_4-">Bau-Simulator</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer"><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">34,99€</div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh Down"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">▼ 25</div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">2</div></td></tr><tr class="weeklytopsellers_TableRow_2-RN6"><td class="weeklytopsellers_HoverCell_3Jiuz"><div data-key="hover div" class="weeklytopsellers_HoverSource_1oW6Q"><div class="weeklytopsellers_HoverMask_N8w56"></div></div></td><td class="weeklytopsellers_RankCell_34h48">100</td><td class="weeklytopsellers_CapsuleCell_18kGH"><a class="weeklytopsellers_TopChartItem_2C5PJ" href="https://store.steampowered.com/bundle/12024/?snr=1_7001_topselling__7003"><img class="weeklytopsellers_CapsuleArt_2dODJ" src="https://cdn.akamai.steamstatic.com/steam/bundles/12024/avwhocict2p7zvez/capsule_231x87.jpg?t=1692279553"><div class="weeklytopsellers_GameName_1n_4-">Northgard: The Viking Age Edition</div></a></td><td class="weeklytopsellers_PriceCell_3IyfU"><div class="weeklytopsellers_PriceWidget_30rPO"><div class="salepreviewwidgets_StoreSalePriceWidgetContainer_tqNH0 StoreSalePriceWidgetContainer salepreviewwidgets_Discounted_35-Ub Discounted"><div class="salepreviewwidgets_StoreSaleDiscountBox_2fpFv">-10%</div><div class="salepreviewwidgets_StoreSaleDiscountedPriceCtn_3GLeQ"><div class="salepreviewwidgets_StoreOriginalPrice_1EKGZ">72,89€</div><div class="salepreviewwidgets_StoreSalePriceBox_Wh0L8">65,60€</div></div></div></div></td><td class="weeklytopsellers_ChangeCell_1ZdIh"><div class="weeklytopsellers_Tooltip_2OA1J Focusable"><span class="weeklytopsellers_ListWeeksDebut_3VOg1">Neu</span></div></td><td class="weeklytopsellers_WeeksCell_xm7Jp"><div class="weeklytopsellers_Tooltip_2OA1J Focusable">1</div></td></tr></tbody></table>
'''

# BeautifulSoup-Objekt erstellen
soup = BeautifulSoup(html, 'html.parser')

# Alle Zeilen (tr-Tags) in der Tabelle finden
rows = soup.find_all('tr', class_='weeklytopsellers_TableRow_2-RN6')

app_ids = []

# Schleife durch die Zeilen
for row in rows:
    # Die zweite Spalte (Index 1) in jeder Zeile finden und den Text extrahieren
    app_number = row.find_all('td')[2].find('a')['href'].split('/')[-2]
    app_ids.append(app_number)

len(app_ids)
# Out:
# 100

# %%
import steamtable
html = steamtable.html
soup = BeautifulSoup(html, 'html.parser')
rows = soup.find_all('tr', class_='weeklytopsellers_TableRow_2-RN6')
app_ids = []
for row in rows:
    app_number = row.find_all('td')[2].find('a')['href'].split('/')[-2]
    app_ids.append(app_number)

len(app_ids)
# Out:
# 100

# %%
#get top 100 games from steam
url = 'https://store.steampowered.com/charts/topselling'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')
games = soup.find_all('a', class_="tab_item")
game_list = []
for game in games:
    game_list.append(game.text.strip())
game_list = game_list[1:101]

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="responsive" lang="en">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="width=device-width,initial-scale=1" name="viewport"/>
# <meta content="#171a21" name="theme-color"/>
# <title>Steam Charts</title>
# <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://store.akamai.steamstatic.com/public/shared/css/motiva_sans.css?v=Rc2hpzg2Ex3T&amp;l=english" rel="stylesheet" type="text/css"/>
# <link href="https://store.akamai.steamstatic.com/public/shared/css/shared_global.css?v=MIg0pk6GiDqL&amp;l=english" rel="stylesheet" type="text/css"/>
# <link href="https://store.akamai.steamstatic.com/public/shared/css/buttons.css?v=6PFqex5UPprb&amp;l=english" rel="stylesheet" type="text/css"/>
# <link href="https://store.akamai.steamstatic.com/public/css/v6/store.css?v=liR58qf5nPDu&amp;l=english" rel="stylesheet" type="text/css"/>
# ...

# %%
games = soup.find_all(class_="salepreviewwidgets_CapsuleImage_cODQh")
games
# Out:
# []

# %%
app_ids = [730, 2195250, 1091500, 2138330]

import time
import requests
import pandas as pd
from urllib.parse import quote


def get_data_from_steam(app_ids):
    language = 'english'
    num_per_page = 100
    day_range = 365
    filters = ['all', 'recent', 'updated']

    total_reviews_to_download = 400

    print('total expected reviews to download: ' + str(total_reviews_to_download*len(filters)*len(app_ids)))

    data_all = pd.DataFrame()
    data_sum = pd.DataFrame()

    for app_id in app_ids:
        for filter in filters:
            reviews_downloaded = 0
            cursor = '*'

            while reviews_downloaded < total_reviews_to_download:
                try:
                    url = 'https://store.steampowered.com/appreviews/' + str(app_id) + '?json=1' + '&cursor=' + str(cursor) + '&language=' + str(language) + '&num_per_page=' + str(num_per_page) + '&filter=' + str(filter) + '&day_range=' + str(day_range)
                    response = requests.get(url)

                    cursor_new = quote(response.json()['cursor'])

                    data_tmp = pd.DataFrame(response.json()['reviews'])
                    data_tmp['app_id'] = app_id
                    data_all = pd.concat([data_all, data_tmp], ignore_index=True)
                    reviews_downloaded += len(data_tmp)

                    if cursor_new == cursor:
                        break
                    else:  
                        cursor = cursor_new

                except:
                    break
            time.sleep(2)
            if reviews_downloaded < total_reviews_to_download:
                print('fewer downloads than expected - app_id index: ' + str(app_ids.index(app_id)) + ', app_id: ' + str(app_id) + ', filter: ' + str(filter) + ', reviews downloaded: '  + str(reviews_downloaded) + ', url: ' + url)
    
    print('total downloaded: ' + str(len(data_all)))

    

    return data_all

df = get_data_from_steam(app_ids)
# Out:
# total expected reviews to download: 4800
# total downloaded: 4894

# %%
#import libaries
import pandas as pd
import steamreviews
import json
from bs4 import BeautifulSoup
import requests

app_ids = [730, 570]
language = 'english'
num_per_page = 100
filters = ['all', 'recent', 'updated']

total_reviews_to_download = 400

data_all = pd.DataFrame()

for app_id in app_ids:
    for filter in filters:
        reviews_downloaded = 0
        cursor = '*'

        while reviews_downloaded < total_reviews_to_download:
            try:
                url = 'https://store.steampowered.com/appreviews/' + str(app_id) + '?json=1' + '&cursor=' + str(cursor) + '&language=' + str(language) + '&num_per_page=' + str(num_per_page) + '&filter=' + str(filter)
                response = requests.get(url)

                cursor_new = response.json()['cursor']

                data_tmp = pd.DataFrame(response.json()['reviews'])
                data_tmp['app_id'] = app_id
                data_all = pd.concat([data_all, data_tmp], ignore_index=True)
                reviews_downloaded += len(data_tmp)

                if cursor_new == cursor:
                    break
                else:  
                    cursor = cursor_new
            except:
                break

# %%
data_all_2 = pd.DataFrame()
data_all_2 = data_all[['app_id', 'recommendationid', 'review', 'voted_up', 'votes_up', 'votes_funny', 'weighted_vote_score']]
# Out:
#       app_id recommendationid  \
# 0        730        146314267
# 1        730        147244655
# 2        730        147189280
# 3        730        147147909
# 4        730        145932685
# ...      ...              ...
# 1497     570         30001949
# 1498     570         29886618
# 1499     570         29497649
# 1500     570         29651267
# 1501     570         30002674
#
#                                                  review  voted_up  votes_up  \
# 0     this game is amazing\ni got made fun of for be...      True      3965
# 1     167 Hard-working achievements gone… How dare y...     False       573
# 2     Valve did an Activision-Blizzard, and force up...     False       460
# 3          Final Review for the CSGO , end of an era!!!      True      1002
# 4                         Good game, ruined by cheaters      True       850
# ...                                                 ...       ...       ...
# ...

# %%
data_all_2
# Out:
#       app_id recommendationid  \
# 0        730        146314267
# 1        730        147244655
# 2        730        147189280
# 3        730        147147909
# 4        730        145932685
# ...      ...              ...
# 1497     570         30001949
# 1498     570         29886618
# 1499     570         29497649
# 1500     570         29651267
# 1501     570         30002674
#
#                                                  review  voted_up  votes_up  \
# 0     this game is amazing\ni got made fun of for be...      True      3965
# 1     167 Hard-working achievements gone… How dare y...     False       573
# 2     Valve did an Activision-Blizzard, and force up...     False       460
# 3          Final Review for the CSGO , end of an era!!!      True      1002
# 4                         Good game, ruined by cheaters      True       850
# ...                                                 ...       ...       ...
# ...

# %%
import sqlite3

def send_to_database(df):
    conn = sqlite3.connect('data/db_steam.db')
    df.to_sql('reviews', conn, if_exists='replace', index=False)
    conn.close()

send_to_database(data_all_2)

# %% [markdown]
# # DONE

# %% [markdown]
# ## steamdata.py

# %%
#main function for getting data
def get_data(app_ids):
    save_reviews365(app_ids)
    data_list = get_data_list(app_ids)
    return data_list

# save reviews of last 365 days via steamreviews
def save_reviews365(app_ids):
    request_params = dict()
    request_params['language'] = 'english'
    request_params['num_per_page'] = '100'
    request_params['filter'] = 'recent'
    request_params['day_range'] = '365'

    while True:
        try:
            review_dict, query_count = steamreviews.download_reviews_for_app_id_batch(app_ids, chosen_request_params=request_params)
        except:
            break

# get data_list from json files
def get_data_list(app_ids):
    data_list = []
    for app_id in app_ids:
        file_path = 'data/review_' + str(app_id) + '.json'
        with open(file_path, 'r') as json_file:
            data_json = json.load(json_file)
        for review_id, review_info in data_json['reviews'].items():
            row = {
                'app_id': app_id,
                'recommendationid': review_info['recommendationid'],
                'review': review_info['review'],
                'voted_up': review_info['voted_up'],
                'votes_up': review_info['votes_up'],
                'votes_funny': review_info['votes_funny'],
                'weighted_vote_score': review_info['weighted_vote_score'],
                'comment_count': review_info['comment_count']
            }
            data_list.append(row)
    return data_list

# %%
app_ids = [2586870, 1497440, 1036240, 1902690, 1607250]

data_list = get_data(app_ids)

# %%
#get recommendationid from data_list
data_list
# Out:
# [{'app_id': 2586870,
#   'recommendationid': '147379813',
#   'review': "My friend who I play CS:GO with said if I post a review on Soul's Spectrum: Awakening and it gets 75 likes and 30 Awards that he will buy me a RTX 3060 and 1 Kilo of Lemon . So im just gonna leave this here. Help a brotha",
#   'voted_up': True,
#   'votes_up': 4,
#   'votes_funny': 0,
#   'weighted_vote_score': '0.196229293942451477',
#   'comment_count': 0},
#  {'app_id': 2586870,
#   'recommendationid': '147376402',
#   'review': "I really loved playing through the prologue! Puzzles are good for starting to learn how the game works, but still really fun and challenging!\nGraphics are really polished and pleasant to watch, and the adaptive soundtrack is really nice!\nBeing the prologue the story doesn't start yet, but the dialogues gave me a sense of mistery, and now I'm really looking forward to play the complete game! :D",
#   'voted_up': True,
#   'votes_up': 1,
#   'votes_funny': 0,
# ...
